# %% [markdown]
# jupyter data science workflow

# %%
URL = "https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD"

# %%
from urllib.request import urlretrieve

# %%
urlretrieve(URL, 'Fremont.csv')
# Out:
# ('Fremont.csv', <http.client.HTTPMessage at 0x11ccbc6d0>)

# %%
# !head Fremont.csv
# Out:
# Date,Fremont Bridge Total,Fremont Bridge East Sidewalk,Fremont Bridge West Sidewalk
# 10/03/2012 12:00:00 AM,13,4,9
# 10/03/2012 01:00:00 AM,10,4,6
# 10/03/2012 02:00:00 AM,2,1,1
# 10/03/2012 03:00:00 AM,5,2,3
# 10/03/2012 04:00:00 AM,7,6,1
# 10/03/2012 05:00:00 AM,31,21,10
# 10/03/2012 06:00:00 AM,155,105,50
# 10/03/2012 07:00:00 AM,352,257,95
# 10/03/2012 08:00:00 AM,437,291,146

# %%
import pandas as pd
data = pd.read_csv('Fremont.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
# %matplotlib inline
data.resample('W').sum().plot();

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
data.columns = ['Total','West', 'East']
data.resample('W').sum().plot();

# %%
#data['Total'] = data['West'] + data['East']

ax = data.resample('D').sum().rolling(365).sum().plot();
ax.set_ylim(0, None);

# %%
data.groupby(data.index.time).mean().plot();

# %%
pd.__version__
# Out:
# '1.1.0'

# %%
pivoted = data.pivot_table('Total', index=data.index.time, columns=data.index.date)
pivoted.iloc[:5, :5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0

# %%
pivoted.plot(legend=False, alpha=0.01);

# %%
data
# Out:
#                      Total  West   East
# Date
# 2012-10-03 00:00:00   13.0   4.0    9.0
# 2012-10-03 01:00:00   10.0   4.0    6.0
# 2012-10-03 02:00:00    2.0   1.0    1.0
# 2012-10-03 03:00:00    5.0   2.0    3.0
# 2012-10-03 04:00:00    7.0   6.0    1.0
# ...                    ...   ...    ...
# 2020-07-31 19:00:00  191.0  87.0  104.0
# 2020-07-31 20:00:00  141.0  54.0   87.0
# 2020-07-31 21:00:00   75.0  29.0   46.0
# 2020-07-31 22:00:00   34.0  18.0   16.0
# 2020-07-31 23:00:00   12.0   7.0    5.0
#
# [134870 rows x 3 columns]

# %%
URL_2 = 'https://data.seattle.gov/api/views/mdbt-9ykn/rows.csv?accessType=DOWNLOAD'

# %%
urlretrieve(URL_2, 'Fremont2.csv')
# Out:
# ('Fremont2.csv', <http.client.HTTPMessage at 0x11ccbc5b0>)

# %%
# !head Fremont2.csv
# Out:
# Date,Fremont Bridge West Sidewalk,Fremont Bridge East Sidewalk
# 12/01/2018 12:00:00 AM,56794,37088
# 11/01/2016 12:00:00 AM,70986,57208
# 12/01/2016 12:00:00 AM,43104,34770
# 08/01/2014 12:00:00 AM,112500,112480
# 01/01/2014 12:00:00 AM,57798,61948
# 11/01/2013 12:00:00 AM,57518,61022
# 06/01/2017 12:00:00 AM,121956,93646
# 03/01/2013 12:00:00 AM,63292,68886
# 03/01/2017 12:00:00 AM,66088,51406

# %%
data2 = pd.read_csv('Fremont2.csv', index_col='Date', parse_dates=True)

# %%
data2.head()
# Out:
#             Fremont Bridge West Sidewalk  Fremont Bridge East Sidewalk
# Date
# 2018-12-01                         56794                         37088
# 2016-11-01                         70986                         57208
# 2016-12-01                         43104                         34770
# 2014-08-01                        112500                        112480
# 2014-01-01                         57798                         61948

# %%
data2
# Out:
#             Fremont Bridge West Sidewalk  Fremont Bridge East Sidewalk
# Date
# 2018-12-01                         56794                         37088
# 2016-11-01                         70986                         57208
# 2016-12-01                         43104                         34770
# 2014-08-01                        112500                        112480
# 2014-01-01                         57798                         61948
# ...                                  ...                           ...
# 2013-06-01                         95682                        102878
# 2017-09-01                        111264                         81732
# 2013-08-01                        102700                        106398
# 2018-08-01                        135544                         88074
# 2014-04-01                         83992                         89718
#
# [94 rows x 2 columns]

# %%
data2.iloc[:5]
# Out:
#             Fremont Bridge West Sidewalk  Fremont Bridge East Sidewalk
# Date
# 2018-12-01                         56794                         37088
# 2016-11-01                         70986                         57208
# 2016-12-01                         43104                         34770
# 2014-08-01                        112500                        112480
# 2014-01-01                         57798                         61948

# %%
data.iloc[:5]
# Out:
#                      Total  West  East
# Date
# 2012-10-03 00:00:00   13.0   4.0   9.0
# 2012-10-03 01:00:00   10.0   4.0   6.0
# 2012-10-03 02:00:00    2.0   1.0   1.0
# 2012-10-03 03:00:00    5.0   2.0   3.0
# 2012-10-03 04:00:00    7.0   6.0   1.0
